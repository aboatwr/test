# %%
import pandas as pd

# %%
test = pd.read_csv("/Users/Abbie/Documents/PhD/spring 2022/price/508 paper/data/Berkeley_tracking_the_sun/TTS_LBNL_public_file_27-Jan-2022_p1.csv")
# Out:
# /Users/Abbie/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (1,2,3,14,15,17,19,27,28,30,31,33,34,37,38,39,52,53,55,56,58,59,76,77,78) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
test
# Out:
#                                  dataProvider1                 dataProvider2  \
# 0                       Arizona Public Service                            -1
# 1                       Arizona Public Service                            -1
# 2                       Arizona Public Service                            -1
# 3                       Arizona Public Service                            -1
# 4                       Arizona Public Service                            -1
# ...                                        ...                           ...
# 999995  California Public Utilities Commission                            -1
# 999996  California Public Utilities Commission  California Energy Commission
# 999997  California Public Utilities Commission                            -1
# 999998  California Public Utilities Commission                            -1
# 999999  California Public Utilities Commission                            -1
#
# ...
